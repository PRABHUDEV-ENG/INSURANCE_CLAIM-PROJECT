# %%
import pandas as pd
import seaborn as sb
df=pd.read_csv(r"C:\Users\K.PRABHU\Downloads\dsp lab\claim_insurance.csv")

# %%
df.head()
# Out:
#    subscription_length  vehicle_age  customer_age  region_code  \
# 0                    3            6            41           20
# 1                   10            9            35           11
# 2                    3            1            44           20
# 3                    6            2            44            1
# 4                    4            5            56            4
#
#    region_density  segment  model  fuel_type  engine_type  airbags  ...  \
# 0            8794        4      5          1            3        6  ...
# 1           27003        3     10          1           10        2  ...
# 2            8794        4      5          1            3        6  ...
# 3           73430        0      0          0            6        2  ...
# 4            5410        2      6          1            4        2  ...
#
#    is_power_door_locks  is_central_locking  is_power_steering  \
# 0                    1                   1                  1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58592 entries, 0 to 58591
# Data columns (total 39 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   subscription_length               58592 non-null  int64
#  1   vehicle_age                       58592 non-null  int64
#  2   customer_age                      58592 non-null  int64
#  3   region_code                       58592 non-null  int64
#  4   region_density                    58592 non-null  int64
#  5   segment                           58592 non-null  int64
#  6   model                             58592 non-null  int64
#  7   fuel_type                         58592 non-null  int64
#  8   engine_type                       58592 non-null  int64
#  9   airbags                           58592 non-null  int64
#  10  is_esc                            58592 non-null  int64
#  11  is_adjustable_steering            58592 non-null  int64
# ...

# %%
X=df.drop("claim_status",axis=1)
Y=df["claim_status"]

# %%
X
# Out:
#        subscription_length  vehicle_age  customer_age  region_code  \
# 0                        3            6            41           20
# 1                       10            9            35           11
# 2                        3            1            44           20
# 3                        6            2            44            1
# 4                        4            5            56            4
# ...                    ...          ...           ...          ...
# 58587                    8           13            48           17
# 58588                    3           11            37           15
# 58589                    8           11            35           20
# 58590                    8           18            44           20
# 58591                    8            2            49            3
#
#        region_density  segment  model  fuel_type  engine_type  airbags  ...  \
# 0                8794        4      5          1            3        6  ...
# ...

# %%
Y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 58587    0
# 58588    0
# 58589    0
# 58590    0
# 58591    0
# Name: claim_status, Length: 58592, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['rear_brakes_type']=encoder.fit_transform(df['rear_brakes_type'])
df['steering_type']=encoder.fit_transform(df['steering_type'])
df['transmission_type']=encoder.fit_transform(df['transmission_type'])

# %%
X=df.drop(columns=['rear_brakes_type','steering_type','transimission_type'])

# %%
X.dtypes
# Out:
# subscription_length                 int64
# vehicle_age                         int64
# customer_age                        int64
# region_code                         int64
# region_density                      int64
# segment                             int64
# model                               int64
# fuel_type                           int64
# engine_type                         int64
# airbags                             int64
# is_esc                              int64
# is_adjustable_steering              int64
# is_tpms                             int64
# is_parking_sensors                  int64
# is_parking_camera                   int64
# displacement                        int64
# cylinder                            int64
# transmission_type                   int64
# turning_radius                      int64
# length                              int64
# width                               int64
# gross_weight                        int64
# ...

# %%
Y.dtypes
# Out:
# dtype('int64')

# %%
df.head()
# Out:
#    subscription_length  vehicle_age  customer_age  region_code  \
# 0                    3            6            41           20
# 1                   10            9            35           11
# 2                    3            1            44           20
# 3                    6            2            44            1
# 4                    4            5            56            4
#
#    region_density  segment  model  fuel_type  engine_type  airbags  ...  \
# 0            8794        4      5          1            3        6  ...
# 1           27003        3     10          1           10        2  ...
# 2            8794        4      5          1            3        6  ...
# 3           73430        0      0          0            6        2  ...
# 4            5410        2      6          1            4        2  ...
#
#    is_power_door_locks  is_central_locking  is_power_steering  \
# 0                    1                   1                  1
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# %%
import pandas as pd

df = pd.read_csv("claim_insurance.csv")

# remove extra spaces
df.columns = df.columns.str.strip()

# drop wrong column
df = df.drop(columns=['transimission_type'], errors='ignore')

# %%
X.dtypes
# Out:
# subscription_length                 int64
# vehicle_age                         int64
# customer_age                        int64
# region_code                         int64
# region_density                      int64
# segment                             int64
# model                               int64
# fuel_type                           int64
# engine_type                         int64
# airbags                             int64
# is_esc                              int64
# is_adjustable_steering              int64
# is_tpms                             int64
# is_parking_sensors                  int64
# is_parking_camera                   int64
# displacement                        int64
# cylinder                            int64
# transmission_type                   int64
# turning_radius                      int64
# length                              int64
# width                               int64
# gross_weight                        int64
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, Y_train)
Y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(Y_test, Y_pred))
# Out:
# Logistic Regression Accuracy: 1.0
# c:\Users\K.PRABHU\.conda\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

df = DecisionTreeClassifier()
df.fit(X_train, Y_train)

Y_pred_df = df.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(Y_test, Y_pred_df))
# Out:
# Decision Tree Accuracy: 1.0

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100)
rf.fit(X_train, Y_train)

Y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(Y_test, Y_pred_rf))
# Out:
# Random Forest Accuracy: 1.0

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, Y_train)

Y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(Y_test, Y_pred_knn))
# Out:
# KNN Accuracy: 0.9419745712091475

# %%
from sklearn.svm import SVC

svm = SVC(kernel='rbf')  

svm.fit(X_train, Y_train)

Y_pred_svm = svm.predict(X_test)

print("SVM Accuracy:", accuracy_score(Y_test, Y_pred_svm))
# Out:
# SVM Accuracy: 0.9363426913559177

# %%
print("KNN:", accuracy_score(Y_test, Y_pred_knn))
print("SVM:", accuracy_score(Y_test, Y_pred_svm))
# Out:
# KNN: 0.9419745712091475
# SVM: 0.9363426913559177

# %%
# 1. Define models
log_model = LogisticRegression()
dt_model = DecisionTreeClassifier()
rf_model = RandomForestClassifier()

# 2. Train models
log_model.fit(X_train, Y_train)
dt_model.fit(X_train, Y_train)
rf_model.fit(X_train, Y_train)

# 3. Put in dictionary
models = {
    "Logistic Regression": log_model,
    "Decision Tree": dt_model,
    "Random Forest": rf_model
}
for name, model in models.items():
    model.fit(X_train, Y_train)   # Train
    
    y_pred = model.predict(X_test)  # Predict
    
    acc = accuracy_score(Y_test, Y_pred) * 100
    prec = precision_score(Y_test, Y_pred, average='macro') * 100
    rec = recall_score(Y_test, Y_pred, average='macro') * 100
    f1 = f1_score(Y_test, Y_pred, average='macro') * 100
    
    results.append([name, round(acc,2), round(prec,2), round(rec,2), round(f1,2)])

# Print results
for r in results:
    print(r)
# Out:
# c:\Users\K.PRABHU\.conda\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\K.PRABHU\.conda\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
